# %% [markdown]
# #  **Where Art Meets Intelligence**
#
# <center>
# <img src="https://api.nga.gov/iiif/10b60beb-8b9f-480b-8734-7f00b20284d8/full/!200,200/0/default.jpg"">
# </center>
#
# Art is more than pigment on canvas or ink on paper—it is a language of expression shaped by culture, history, and human imagination. From the textured depth of oil paintings to the fluid spontaneity of watercolors, every artistic medium carries its own story, technique, and identity.
#
# In the digital age, art is no longer confined to galleries and museums. Vast collections are being archived, analyzed, and explored using data. Each artwork is accompanied by rich contextual information—titles that hint at meaning, descriptions that narrate intent, and metadata that anchors it in time and space.
#
# This project sits at the intersection of creativity and computation. By leveraging machine learning, we aim to decode patterns hidden within artistic data and automatically identify the medium of an artwork. What may seem like a simple classification task is, in reality, a deeper exploration of how language, structure, and visual cues reflect artistic techniques.
#
# Can a model distinguish the delicate transparency of watercolor from the layered richness of oil paint? Can it learn the subtle signals embedded in words and forms?
#
# Let’s find out.....

# %% [markdown]
# # **Problem Framing**
#
# Target:
# Predict artistic medium (multi-class classification)
#
# Inputs:
#
# - Text → titles, descriptions, captions
# - Structured → year, dimensions, category
# - Optional → image URL
#
# This is essentially:
#
# $$f(text,metadata,image)→medium$$

# %% [markdown]
# # **About Dataset**

# %% [markdown]
# **Columns**
#
# - id — Unique identifier for each artwork
# - t — Title of the artwork
# - txt — Detailed textual description
# - cap — Caption or short summary
# - img — Image URL (can be used for vision models)
# - y — Target label (only present in train.csv)

# %% [markdown]
# **Metadata Columns**
# - y0 — Start year of the artwork
#
# - y1 — End year of the artwork
#
# - dt — Display date (text format)
#
# - dim — Dimensions (text format)
#
# - width, height — Numeric size attributes (if available)
#
# - cat — Category or classification label
#
# - tp — Data type
#
# - tag — Tags or keywords associated with the artwork
#
# - note — Additional notes or remarks

# %% [markdown]
# # **Libraries**

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.patches as mpatches

import seaborn as sns 
import pandas as pd 

import warnings
warnings.filterwarnings('ignore')

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (classification_report, confusion_matrix, accuracy_score, f1_score)
from sklearn.model_selection import StratifiedKFold, cross_val_score
import lightgbm as lgb
import scipy.sparse as sp
import joblib

# %%
plt.style.use('dark_background')

plt.rcParams.update({
    # Figure
    "figure.figsize": (10, 6),
    "figure.dpi": 120,

    # Axes
    "axes.facecolor": "#111111",
    "axes.edgecolor": "white",
    "axes.labelcolor": "white",
    "axes.titlesize": 16,
    "axes.labelsize": 12,
    "axes.grid": True,

    # Grid
    "grid.color": "#444444",
    "grid.linestyle": "--",
    "grid.linewidth": 0.6,

    # Ticks
    "xtick.color": "white",
    "ytick.color": "white",

    # Legend
    "legend.facecolor": "#111111",
    "legend.edgecolor": "white",
    "legend.fontsize": 10,

    # Lines
    "lines.linewidth": 2,
    "lines.markersize": 6,

    # Font
    "font.size": 11,
    "font.family":      "DejaVu Sans",
})

# %% [markdown]
# # **Data Loading And Basic Overview**

# %%
train = pd.read_csv("train_data.csv")
test  = pd.read_csv("test_data.csv")

train.head()
# Out:
#      id  Unnamed: 0  acc         acc_id      loc  \
# 0  2929        2929    1      1983.1.14      NaN
# 1  3224        3224    1      1951.16.5      NaN
# 2  3351        3351    1  2008.115.2454      NaN
# 3  1736        1736    1       1958.9.7      NaN
# 4  1813        1813    1     1963.10.52  13181.0
#
#                                           t            dt      y0      y1  \
# 0                  Beach Scene at Trouville          1863  1863.0  1863.0
# 1                             Playing Cards  15th century  1400.0  1499.0
# 2                               Agriculture          1939  1939.0  1939.0
# 3  Burning of Old South Church, Bath, Maine       c. 1854  1854.0  1854.0
# 4                                Le gourmet          1901  1901.0  1901.0
#
#              ts  ...                    tp  ord                    txt  \
# 0  1851 to 1875  ...                   NaN  NaN                    NaN
# 1  1300 to 1400  ...                   NaN  NaN                    NaN
# 2  1926 to 1950  ...                   NaN  NaN                    NaN
# 3  1851 to 1875  ...  previous_attribution  1.0  American 19th Century
# 4  1901 to 1925  ...                   NaN  NaN                    NaN
#
#                      tag                         note  eff  \
# 0                    NaN                          NaN  NaN
# 1                    NaN                          NaN  NaN
# 2                    NaN                          NaN  NaN
# 3  American 19th Century  Attribution at time of gift  NaN
# 4                    NaN                          NaN  NaN
#
#                                                  cat  \
# 0  painted surface|Beach|Trouville|French Paintin...
# 1                                            Lombard
# 2                                                NaN
# 3  American|Bath, ME|Old South Church|American Na...
# 4  Eating|Twentieth and Twenty-first Century Pain...
#
#                                                  img  \
# 0  https://api.nga.gov/iiif/85f2142e-1b34-4e75-a0...
# 1  https://api.nga.gov/iiif/717a802a-4449-4cf6-8b...
# 2  https://api.nga.gov/iiif/5b8cada2-0d67-45bb-96...
# 3  https://api.nga.gov/iiif/c8befcd8-4237-4652-ba...
# 4  https://api.nga.gov/iiif/e19a2b28-639c-4d6a-84...
#
#                                                  cap  y
# 0  A oil on wood artwork titled 'Beach Scene at T...  4
# 1  A print artwork titled 'Playing Cards' by Unkn...  5
# 2  A print artwork titled 'Agriculture' by Unknow...  5
# 3  A oil on canvas artwork titled 'Burning of Old...  2
# 4  A oil on canvas artwork titled 'Le gourmet' by...  2
#
# [5 rows x 57 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           4000 non-null   int64
#  1   Unnamed: 0                   4000 non-null   int64
#  2   acc                          4000 non-null   int64
#  3   acc_id                       4000 non-null   object
#  4   loc                          667 non-null    float64
#  5   t                            4000 non-null   object
#  6   dt                           3746 non-null   object
#  7   y0                           3999 non-null   float64
#  8   y1                           3999 non-null   float64
#  9   ts                           3999 non-null   object
#  10  dim                          3768 non-null   object
#  11  inscription                  2333 non-null   object
#  12  markings                     166 non-null    object
#  13  attributioninverted          4000 non-null   object
#  14  attribution                  4000 non-null   object
#  15  provenancetext               3416 non-null   object
#  16  creditline                   4000 non-null   object
#  17  classification               4000 non-null   object
#  18  subclassification            107 non-null    object
#  19  visualbrowserclassification  4000 non-null   object
#  20  parentid                     310 non-null    float64
#  21  isvirtual                    4000 non-null   int64
#  22  departmentabbr               4000 non-null   object
#  23  portfolio                    374 non-null    object
#  24  series                       385 non-null    object
#  25  volume                       6 non-null      object
#  26  watermarks                   161 non-null    object
#  27  lastdetectedmodification     4000 non-null   object
#  28  wikidataid                   3887 non-null   object
#  29  customprinturl               150 non-null    object
#  30  label                        4000 non-null   object
#  31  uuid                         4000 non-null   object
#  32  iiifurl                      4000 non-null   object
#  33  iiifthumburl                 4000 non-null   object
#  34  viewtype                     4000 non-null   object
#  35  sequence                     4000 non-null   float64
#  36  width                        4000 non-null   int64
#  37  height                       4000 non-null   int64
#  38  maxpixels                    1308 non-null   float64
#  39  created                      4000 non-null   object
#  40  modified                     4000 non-null   object
#  41  depictstmsobjectid           4000 non-null   int64
#  42  assistivetext                717 non-null    object
#  43  element                      3736 non-null   object
#  44  dimensiontype                3736 non-null   object
#  45  dimension                    3736 non-null   float64
#  46  unitname                     3736 non-null   object
#  47  tp                           503 non-null    object
#  48  ord                          503 non-null    float64
#  49  txt                          503 non-null    object
#  50  tag                          428 non-null    object
#  51  note                         382 non-null    object
#  52  eff                          97 non-null     object
#  53  cat                          3855 non-null   object
#  54  img                          4000 non-null   object
#  55  cap                          4000 non-null   object
#  56  y                            4000 non-null   int64
# dtypes: float64(8), int64(8), object(41)
# memory usage: 1.7+ MB

# %%
train.iloc[0]
# Out:
# id                                                                          2929
# Unnamed: 0                                                                  2929
# acc                                                                            1
# acc_id                                                                 1983.1.14
# loc                                                                          NaN
# t                                                       Beach Scene at Trouville
# dt                                                                          1863
# y0                                                                        1863.0
# y1                                                                        1863.0
# ts                                                                  1851 to 1875
# dim                            overall: 34.8 x 57.5 cm (13 11/16 x 22 5/8 in....
# inscription                                             lower left: E. Boudin 63
# markings                                                                     NaN
# attributioninverted                                               Boudin, Eugène
# attribution                                                        Eugène Boudin
# provenancetext                 Charles de Bériot, Paris; (his sale, Hôtel Dro...
# creditline                                Collection of Mr. and Mrs. Paul Mellon
# classification                                                          Painting
# subclassification                                                            NaN
# visualbrowserclassification                                             painting
# parentid                                                                     NaN
# isvirtual                                                                      0
# departmentabbr                                                                CF
# portfolio                                                                    NaN
# series                                                                       NaN
# volume                                                                       NaN
# watermarks                                                                   NaN
# lastdetectedmodification                              2019-10-28 22:01:34.883-04
# wikidataid                                                             Q20188635
# customprinturl                                                               NaN
# label                                                                oil_on_wood
# uuid                                        85f2142e-1b34-4e75-a077-62de44276f88
# iiifurl                        https://api.nga.gov/iiif/85f2142e-1b34-4e75-a0...
# iiifthumburl                   https://api.nga.gov/iiif/85f2142e-1b34-4e75-a0...
# viewtype                                                                 primary
# sequence                                                                     0.0
# width                                                                       5167
# height                                                                      3104
# maxpixels                                                                    NaN
# created                                                   2007-09-06 14:34:25-04
# modified                                                  2022-08-31 12:02:48-04
# depictstmsobjectid                                                         61364
# assistivetext                  About two dozen men and women sit in straight-...
# element                                                                  overall
# dimensiontype                                                              width
# dimension                                                                   57.5
# unitname                                                             centimeters
# tp                                                                           NaN
# ord                                                                          NaN
# txt                                                                          NaN
# tag                                                                          NaN
# note                                                                         NaN
# eff                                                                          NaN
# cat                            painted surface|Beach|Trouville|French Paintin...
# img                            https://api.nga.gov/iiif/85f2142e-1b34-4e75-a0...
# cap                            A oil on wood artwork titled 'Beach Scene at T...
# y                                                                              4
# Name: 0, dtype: object

# %% [markdown]
# # **Data Cleaning**

# %%
# extra columns 
cols_to_exclude = ['t', 'txt', 'cap', 'img', 'y0', 'y1', 'dt', 'dim', 'width', 'height', 'cat', 'tp', 'tag', 'note', 'y']
train_other = train[[col for col in train.columns if col not in cols_to_exclude]]
train_other.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           4000 non-null   int64
#  1   Unnamed: 0                   4000 non-null   int64
#  2   acc                          4000 non-null   int64
#  3   acc_id                       4000 non-null   object
#  4   loc                          667 non-null    float64
#  5   ts                           3999 non-null   object
#  6   inscription                  2333 non-null   object
#  7   markings                     166 non-null    object
#  8   attributioninverted          4000 non-null   object
#  9   attribution                  4000 non-null   object
#  10  provenancetext               3416 non-null   object
#  11  creditline                   4000 non-null   object
#  12  classification               4000 non-null   object
#  13  subclassification            107 non-null    object
#  14  visualbrowserclassification  4000 non-null   object
#  15  parentid                     310 non-null    float64
#  16  isvirtual                    4000 non-null   int64
#  17  departmentabbr               4000 non-null   object
#  18  portfolio                    374 non-null    object
#  19  series                       385 non-null    object
#  20  volume                       6 non-null      object
#  21  watermarks                   161 non-null    object
#  22  lastdetectedmodification     4000 non-null   object
#  23  wikidataid                   3887 non-null   object
#  24  customprinturl               150 non-null    object
#  25  label                        4000 non-null   object
#  26  uuid                         4000 non-null   object
#  27  iiifurl                      4000 non-null   object
#  28  iiifthumburl                 4000 non-null   object
#  29  viewtype                     4000 non-null   object
#  30  sequence                     4000 non-null   float64
#  31  maxpixels                    1308 non-null   float64
#  32  created                      4000 non-null   object
#  33  modified                     4000 non-null   object
#  34  depictstmsobjectid           4000 non-null   int64
#  35  assistivetext                717 non-null    object
#  36  element                      3736 non-null   object
#  37  dimensiontype                3736 non-null   object
#  38  dimension                    3736 non-null   float64
#  39  unitname                     3736 non-null   object
#  40  ord                          503 non-null    float64
#  41  eff                          97 non-null     object
# dtypes: float64(6), int64(5), object(31)
# memory usage: 1.3+ MB

# %%
train_other.iloc[0]
# Out:
# id                                                                          2929
# Unnamed: 0                                                                  2929
# acc                                                                            1
# acc_id                                                                 1983.1.14
# loc                                                                          NaN
# ts                                                                  1851 to 1875
# inscription                                             lower left: E. Boudin 63
# markings                                                                     NaN
# attributioninverted                                               Boudin, Eugène
# attribution                                                        Eugène Boudin
# provenancetext                 Charles de Bériot, Paris; (his sale, Hôtel Dro...
# creditline                                Collection of Mr. and Mrs. Paul Mellon
# classification                                                          Painting
# subclassification                                                            NaN
# visualbrowserclassification                                             painting
# parentid                                                                     NaN
# isvirtual                                                                      0
# departmentabbr                                                                CF
# portfolio                                                                    NaN
# series                                                                       NaN
# volume                                                                       NaN
# watermarks                                                                   NaN
# lastdetectedmodification                              2019-10-28 22:01:34.883-04
# wikidataid                                                             Q20188635
# customprinturl                                                               NaN
# label                                                                oil_on_wood
# uuid                                        85f2142e-1b34-4e75-a077-62de44276f88
# iiifurl                        https://api.nga.gov/iiif/85f2142e-1b34-4e75-a0...
# iiifthumburl                   https://api.nga.gov/iiif/85f2142e-1b34-4e75-a0...
# viewtype                                                                 primary
# sequence                                                                     0.0
# maxpixels                                                                    NaN
# created                                                   2007-09-06 14:34:25-04
# modified                                                  2022-08-31 12:02:48-04
# depictstmsobjectid                                                         61364
# assistivetext                  About two dozen men and women sit in straight-...
# element                                                                  overall
# dimensiontype                                                              width
# dimension                                                                   57.5
# unitname                                                             centimeters
# ord                                                                          NaN
# eff                                                                          NaN
# Name: 0, dtype: object

# %% [markdown]
# ## **Columns with missing values**

# %%
print(train.isnull().sum()[lambda x: x > 0].sort_values(ascending=False))
# Out:
# volume               3994
# eff                  3903
# subclassification    3893
# customprinturl       3850
# watermarks           3839
# markings             3834
# parentid             3690
# portfolio            3626
# note                 3618
# series               3615
# tag                  3572
# tp                   3497
# ord                  3497
# txt                  3497
# loc                  3333
# assistivetext        3283
# maxpixels            2692
# inscription          1667
# provenancetext        584
# element               264
# dimensiontype         264
# dimension             264
# unitname              264
# dt                    254
# dim                   232
# cat                   145
# wikidataid            113
# ts                      1
# y1                      1
# y0                      1
# dtype: int64

# %%
def preprocess(df, is_train=True):
    df = df.copy()

    # Drop useless columns
    drop_cols = ["depictstmsobjectid", "img", "dt", "ts", "dim",
                 "element", "dimensiontype", "unitname", "provenancetext",
                 "acc", "loc", "parentid", "isvirtual", "viewtype",
                 "sequence", "maxpixels", "created", "modified",
                 "wikidataid", "customprinturl", "subclassification",
                 "volume", "eff", "markings", "watermarks", "portfolio",
                 "series", "attributioninverted"]
    df.drop(columns=[c for c in drop_cols if c in df.columns], inplace=True)

    # Fill numeric
    df["y0"].fillna(df["y0"].median(), inplace=True)
    df["y1"].fillna(df["y1"].median(), inplace=True)

    # Dimension — per-class median fill (only on train; use train median on test)
    if is_train and "y" in df.columns:
        df["dimension"] = df.groupby("y")["dimension"].transform(
            lambda x: x.fillna(x.median())
        )
    df["dimension"].fillna(df["dimension"].median(), inplace=True)

    # Engineer numeric features
    df["aspect_ratio"] = df["width"] / df["height"]
    df["date_range"]   = df["y1"] - df["y0"]
    df["decade"]       = (df["y0"] // 10 * 10).astype(int)
    df["log_width"]    = np.log1p(df["width"])
    df["log_height"]   = np.log1p(df["height"])
    df["log_dim"]      = np.log1p(df["dimension"])
    df["year_century"] = (df["y0"] // 100).astype(int)

    # Presence flags for sparse text
    for col in ["txt", "tag", "note", "inscription"]:
        df[f"has_{col}"] = df[col].notna().astype(int)
        df[col] = df[col].fillna("")

    df["cat"] = df["cat"].fillna("")
    df["creditline"] = df["creditline"].fillna("")

    # Combined text column (primary NLP feature)
    df["text_combined"] = (
        df["t"].fillna("") + " " +
        df["attribution"].fillna("") + " " +
        df["classification"].fillna("") + " " +
        df["visualbrowserclassification"].fillna("") + " " +
        df["cat"] + " " +
        df["txt"] + " " +
        df["tag"] + " " +
        df["cap"].fillna("")
    )

    # Leakage check — if label col exists, it may encode the target
    if "label" in df.columns:
        df["label_text"] = df["label"].fillna("unknown")
    else:
        df["label_text"] = "unknown"

    return df

# %%
train.isnull().sum()
# Out:
# id                                0
# Unnamed: 0                        0
# acc                               0
# acc_id                            0
# loc                            3333
# t                                 0
# dt                              254
# y0                                1
# y1                                1
# ts                                1
# dim                             232
# inscription                    1667
# markings                       3834
# attributioninverted               0
# attribution                       0
# provenancetext                  584
# creditline                        0
# classification                    0
# subclassification              3893
# visualbrowserclassification       0
# parentid                       3690
# isvirtual                         0
# departmentabbr                    0
# portfolio                      3626
# series                         3615
# volume                         3994
# watermarks                     3839
# lastdetectedmodification          0
# wikidataid                      113
# customprinturl                 3850
# label                             0
# uuid                              0
# iiifurl                           0
# iiifthumburl                      0
# viewtype                          0
# sequence                          0
# width                             0
# height                            0
# maxpixels                      2692
# created                           0
# modified                          0
# depictstmsobjectid                0
# assistivetext                  3283
# element                         264
# dimensiontype                   264
# dimension                       264
# unitname                        264
# tp                             3497
# ord                            3497
# txt                            3497
# tag                            3572
# note                           3618
# eff                            3903
# cat                             145
# img                               0
# cap                               0
# y                                 0
# dtype: int64

# %%
train.iloc[5]
# Out:
# id                                                                          3774
# Unnamed: 0                                                                  3774
# acc                                                                            1
# acc_id                                                                1939.1.290
# loc                                                                       8210.0
# t                                                              Madonna and Child
# dt                                                                       c. 1440
# y0                                                                        1440.0
# y1                                                                        1440.0
# ts                                                                  1401 to 1500
# dim                            overall: 79 x 51.1 cm (31 1/8 x 20 1/8 in.)\r\...
# inscription                                                                  NaN
# markings                                                                     NaN
# attributioninverted                                           Lippi, Fra Filippo
# attribution                                                    Fra Filippo Lippi
# provenancetext                 Edward Solly [1776-1844], Berlin, by 1819;[1] ...
# creditline                                            Samuel H. Kress Collection
# classification                                                          Painting
# subclassification                                                            NaN
# visualbrowserclassification                                             painting
# parentid                                                                     NaN
# isvirtual                                                                      0
# departmentabbr                                                             CIS-R
# portfolio                                                                    NaN
# series                                                                       NaN
# volume                                                                       NaN
# watermarks                                                                   NaN
# lastdetectedmodification                               2022-03-17 10:01:20.52-04
# wikidataid                                                              Q3842474
# customprinturl                 https://customprints.nga.gov/detail/493896/lip...
# label                                                                    tempera
# uuid                                        2b5b0121-85d6-4c8e-9752-a83fb70d7995
# iiifurl                        https://api.nga.gov/iiif/2b5b0121-85d6-4c8e-97...
# iiifthumburl                   https://api.nga.gov/iiif/2b5b0121-85d6-4c8e-97...
# viewtype                                                                 primary
# sequence                                                                     0.0
# width                                                                      10913
# height                                                                     17037
# maxpixels                                                                    NaN
# created                                                   2013-07-12 14:00:02-04
# modified                                                  2022-05-23 11:11:55-04
# depictstmsobjectid                                                           433
# assistivetext                                                                NaN
# element                                                                  overall
# dimensiontype                                                              width
# dimension                                                                   51.1
# unitname                                                             centimeters
# tp                                                                           NaN
# ord                                                                          NaN
# txt                                                                          NaN
# tag                                                                          NaN
# note                                                                         NaN
# eff                                                                          NaN
# cat                            Renaissance|painted surface|Madonna and Child|...
# img                            https://api.nga.gov/iiif/2b5b0121-85d6-4c8e-97...
# cap                            A tempera artwork titled 'Madonna and Child' b...
# y                                                                              6
# Name: 5, dtype: object

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **1. TARGET CLASS DISTRIBUTION**

# %%
df2 = train.copy()

# %%
np.random.seed(42)

PALETTE = ["#378ADD","#1D9E75","#EF9F27","#D85A30","#D4537E","#7F77DD","#639922","#E24B4A"]

# assigning each target value y to a specific class for EDA
CLASS_NAMES = {
    0:"acrylic",1:"oil_on_canvas",2:"oil_on_wood",
    3:"oil_on_panel",4:"watercolor",5:"tempera",
    6:"ink",7:"print"
}

n = 4000

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
fig.suptitle("Target Class Distribution", fontsize=15, fontweight="500", y=1.01)
 
counts = df2["y"].map(CLASS_NAMES).value_counts().sort_values(ascending=True)
colors_bar = [PALETTE[list(CLASS_NAMES.values()).index(c)] for c in counts.index]
 
axes[0].barh(counts.index, counts.values, color=colors_bar, height=0.6)
for v, label in zip(counts.values, counts.index):
    axes[0].text(v + 12, label, f"{v:,}  ({v/n*100:.1f}%)", va="center", fontsize=9, color="#DBD9D0")
axes[0].set_xlabel("Count")
axes[0].set_title("Class counts", pad=10)
axes[0].set_xlim(0, counts.max() * 1.35)
 
pct = df2["y"].map(CLASS_NAMES).value_counts(normalize=True) * 100
wedge_colors = [PALETTE[list(CLASS_NAMES.values()).index(c)] for c in pct.index]
wedges, texts, autotexts = axes[1].pie(
    pct.values, labels=pct.index, colors=wedge_colors,
    autopct=lambda p: f"{p:.1f}%" if p > 4 else "",
    startangle=140, pctdistance=0.75,
    wedgeprops={"linewidth": 1.5, "edgecolor": "#FAFAF8"}
)
for t in texts: t.set_fontsize(9)
for at in autotexts: at.set_fontsize(8)
axes[1].set_title("Class proportions", pad=10)
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **2. MISSING VALUES DISTRIBUTION**

# %%
miss = train.isnull().mean() * 100
miss = miss.sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 5))
fig.suptitle('Missing Values by Column (kept features)', fontsize=15, fontweight='500')

bar_colors = ["#E24B4A" if v > 50 else "#EF9F27" if v > 10 else "#1D9E75" for v in miss.values]
bars = ax.barh(miss.index, miss.values, color=bar_colors, height=0.6)
for bar, v in zip(bars, miss.values):
    ax.text(v + 0.5, bar.get_y() + bar.get_height()/2, f"{v:.1f}%", va="center", fontsize=9, color="#DBD9D0")

ax.set_xlabel("% Missing")
ax.set_xlim(0, 105)
ax.axvline(50, color="#E24B4A", linewidth=0.8, linestyle="--", alpha=0.6)
ax.axvline(10, color="#EF9F27", linewidth=0.8, linestyle="--", alpha=0.6)
 
patches = [mpatches.Patch(color="#1D9E75", label="<10% missing (safe)"),
           mpatches.Patch(color="#EF9F27", label="10–50% (use carefully)"),
           mpatches.Patch(color="#E24B4A", label=">50% (sparse — optional)")]

ax.legend(handles=patches, fontsize=9, loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **3. YEAR DISTRIBUTION BY CLASS**

# %%
fig, axes = plt.subplots(2, 4, figsize=(15, 6), sharey=False)
fig.suptitle("Start Year (y0) Distribution by Medium Class", fontsize=15, fontweight="500")
axes = axes.flatten()
 
for i, (cls_id, cls_name) in enumerate(CLASS_NAMES.items()):
    sub = df2[df2["y"] == cls_id]["y0"].dropna()
    axes[i].hist(sub, bins=30, color=PALETTE[i], alpha=0.85, edgecolor="white", linewidth=0.5)
    axes[i].set_title(cls_name.replace("_", " "), fontsize=10, color=PALETTE[i], fontweight="500")
    axes[i].set_xlabel("Start year")
    med = sub.median()
    axes[i].axvline(med, color="#DBD9D0", linewidth=1.2, linestyle="--")
    axes[i].text(med+5, axes[i].get_ylim()[1]*0.85, f"med={int(med)}", fontsize=8, color="#DBD9D0")
 
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 4, figsize=(15, 6), sharey=False)
fig.suptitle("End Year (y1) Distribution by Medium Class", fontsize=15, fontweight="500")
axes = axes.flatten()
 
for i, (cls_id, cls_name) in enumerate(CLASS_NAMES.items()):
    sub = df2[df2["y"] == cls_id]["y1"].dropna()
    axes[i].hist(sub, bins=30, color=PALETTE[i], alpha=0.85, edgecolor="white", linewidth=0.5)
    axes[i].set_title(cls_name.replace("_", " "), fontsize=10, color=PALETTE[i], fontweight="500")
    axes[i].set_xlabel("Start year")
    med = sub.median()
    axes[i].axvline(med, color="#DBD9D0", linewidth=1.2, linestyle="--")
    axes[i].text(med+5, axes[i].get_ylim()[1]*0.85, f"med={int(med)}", fontsize=8, color="#DBD9D0")
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **4. NUMERIC FEATURES — BOXPLOTS BY CLASS**

# %%
df2["aspect_ratio"] = df2["width"] / df2["height"]
df2["date_range"]   = df2["y1"] - df2["y0"]
df2["y_label"] = df2["y"].map(CLASS_NAMES)

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 9))
fig.suptitle("Numeric Features by Class", fontsize=15, fontweight="500")
 
numeric_features = [
    ("y0", "Start Year"),
    ("dimension", "Physical Dimension (cm)"),
    ("aspect_ratio", "Aspect Ratio (w/h)"),
    ("date_range", "Date Range (y1 − y0)"),
]
order = list(CLASS_NAMES.values())
 
for ax, (col, title) in zip(axes.flatten(), numeric_features):
    data_by_class = [df2[df2["y"]==k][col].dropna().values for k in CLASS_NAMES.keys()]
    bp = ax.boxplot(data_by_class, patch_artist=True, notch=False,
                    medianprops={"color":"#3D3D3A","linewidth":2},
                    whiskerprops={"linewidth":0.8},
                    capprops={"linewidth":0.8},
                    flierprops={"marker":"o","markersize":2,"alpha":0.3,"markerfacecolor":"gray"})
    for patch, color in zip(bp["boxes"], PALETTE):
        patch.set_facecolor(color)
        patch.set_alpha(0.75)
    ax.set_xticklabels([n.replace("_on_","\non\n") for n in order], fontsize=8)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel("")
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **5. CATEGORICAL FEATURE DISTRIBUTION**

# %%
df2["y_label"] = df2["y"].map(CLASS_NAMES)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle("Categorical Feature Distributions by Class", fontsize=15, fontweight="500")
 
cat_features = [
    ("classification", "Classification"),
    ("visualbrowserclassification", "Visual Browser Classification"),
    ("departmentabbr", "Department"),
]
 
for ax, (col, title) in zip(axes, cat_features):
    ct = pd.crosstab(df2[col], df2["y_label"], normalize="index") * 100
    ct.plot(kind="bar", stacked=True, ax=ax, color=PALETTE[:len(CLASS_NAMES)],
            width=0.65, edgecolor="white", linewidth=0.5)
    ax.set_title(title, fontsize=11)
    ax.set_xlabel("")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right", fontsize=9)
    ax.set_ylabel("% of category")
    ax.legend_.remove()
 
handles = [mpatches.Patch(color=PALETTE[i], label=CLASS_NAMES[i]) for i in range(len(CLASS_NAMES))]
fig.legend(handles=handles, loc="lower center", ncol=4, fontsize=9,
           bbox_to_anchor=(0.5, -0.08), frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **6. HEATMAP**

# %%
numeric_cols = ["y0","y1","dimension","width","height","aspect_ratio","date_range","y"]
corr = df2[numeric_cols].corr()
 
fig, ax = plt.subplots(figsize=(8, 6))
fig.suptitle("6 — Correlation Matrix (Numeric Features)", fontsize=15, fontweight="500")
 
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            annot=True, fmt=".2f", linewidths=0.5, linecolor="#E8E6DE",
            ax=ax, annot_kws={"size": 9}, square=True,
            cbar_kws={"shrink": 0.8})
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right", fontsize=9)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **7. TEXT FEATURE (CAP LENGTH & WORD COUNT)**

# %%
df2["cap_len"]   = df2["cap"].fillna("").str.len()
df2["cap_words"] = df2["cap"].fillna("").str.split().str.len()
df2["t_len"]     = df2["t"].fillna("").str.len()
 
fig, axes = plt.subplots(1, 3, figsize=(14, 5))
fig.suptitle(" Text Feature Length by Class", fontsize=15, fontweight="500")
 
for ax, (col, title) in zip(axes, [
    ("cap_len",   "Caption length (chars)"),
    ("cap_words", "Caption word count"),
    ("t_len",     "Title length (chars)"),
]):
    data = [df2[df2["y"]==k][col].values for k in CLASS_NAMES.keys()]
    vp = ax.violinplot(data, positions=range(len(CLASS_NAMES)),
                       showmedians=True, showextrema=False)
    for i, (body, color) in enumerate(zip(vp["bodies"], PALETTE)):
        body.set_facecolor(color); body.set_alpha(0.7)
    vp["cmedians"].set_color("#3D3D3A"); vp["cmedians"].set_linewidth(2)
    ax.set_xticks(range(len(CLASS_NAMES)))
    ax.set_xticklabels([CLASS_NAMES[k].replace("_on_","\non\n") for k in CLASS_NAMES], fontsize=8)
    ax.set_title(title, fontsize=11)
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **8. TEMPORAL TREND — CLASS PROPORTIONS OVER CENTURIES**

# %%
df2["century"] = (df2["y0"] // 100 * 100).astype("Int64")
century_class = df2.groupby(["century","y_label"]).size().unstack(fill_value=0)
century_class_pct = century_class.div(century_class.sum(axis=1), axis=0) * 100
 
fig, ax = plt.subplots(figsize=(12, 5))
fig.suptitle("Class Proportions Over Time (by Century)", fontsize=15, fontweight="500")
 
century_class_pct.plot(kind="area", stacked=True, ax=ax,
                       color=[PALETTE[list(CLASS_NAMES.values()).index(c)]
                              for c in century_class_pct.columns],
                       alpha=0.8, linewidth=0)
ax.set_xlabel("Century")
ax.set_ylabel("% of artworks")
ax.set_ylim(0, 100)
ax.legend(loc="upper left", fontsize=9, ncol=2, frameon=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **9. DIMENTION SCATTER**

# %%
fig, ax = plt.subplots(figsize=(9, 7))
fig.suptitle("Image Dimensions (pixels): Width vs Height", fontsize=15, fontweight="500")
 
for cls_id, cls_name in CLASS_NAMES.items():
    sub = df2[df2["y"] == cls_id]
    ax.scatter(sub["width"]/1000, sub["height"]/1000,
               label=cls_name.replace("_"," "), color=PALETTE[cls_id],
               alpha=0.35, s=14, linewidths=0)
 
ax.plot([0, 9], [0, 9], "--", color="#FFFFFF", linewidth=1, label="square (1:1)")
ax.set_xlabel("Width (k px)")
ax.set_ylabel("Height (k px)")
ax.legend(fontsize=9, ncol=2, frameon=False, markerscale=2)
plt.tight_layout()
plt.show()

# %%
print("\n" + "="*60)
print("EDA SUMMARY — KEY FINDINGS")
print("="*60)
print(f"\n{'Class':<20} {'N':>6} {'%':>7} {'Median Year':>13} {'Median Dim':>12}")
print("-"*63)
for k, name in CLASS_NAMES.items():
    sub = df2[df2["y"]==k]
    print(f"{name:<20} {len(sub):>6} {len(sub)/n*100:>6.1f}% "
          f"{sub['y0'].median():>13.0f} "
          f"{sub['dimension'].median():>11.1f}cm")
 
print("\nImbalance ratio:", round(df2["y"].value_counts().max() / df2["y"].value_counts().min(), 1), "x")
print("Year range:", int(df2["y0"].min()), "–", int(df2["y0"].max()))
print("Avg aspect ratio:", round(df2["aspect_ratio"].mean(), 2))
# Out:
# ============================================================
# EDA SUMMARY — KEY FINDINGS
# ============================================================
#
# Class                     N       %   Median Year   Median Dim
# ---------------------------------------------------------------
# acrylic                 500   12.5%          1971       101.6cm
# oil_on_canvas           412   10.3%          1885        27.8cm
# oil_on_wood             571   14.3%          1863        75.5cm
# oil_on_panel            490   12.2%          1520        45.6cm
# watercolor              485   12.1%          1870        39.3cm
# tempera                 482   12.0%          1920        23.9cm
# ink                     449   11.2%          1445        46.4cm
# print                   611   15.3%          1878        29.4cm
#
# Imbalance ratio: 1.5 x
# Year range: 1000 – 2021
# Avg aspect ratio: 1.05

# %% [markdown]
# ## **Pre Process The Data**

# %%
train = preprocess(train, is_train=True)
test  = preprocess(test,  is_train=False)

# %%
X = train.drop(columns=["y"])
y = train["y"]
X_test = test.copy()

print(f"Train shape: {X.shape}")
print(f"Test shape:  {X_test.shape}")
print(f"\nClass distribution:\n{y.map(CLASS_NAMES).value_counts()}")
# Out:
# Train shape: (4000, 41)
# Test shape:  (1000, 41)
#
# Class distribution:
# y
# print            611
# oil_on_wood      571
# acrylic          500
# oil_on_panel     490
# watercolor       485
# tempera          482
# ink              449
# oil_on_canvas    412
# Name: count, dtype: int64

# %%
# Feature groups
TEXT_COL     = "text_combined"
LABEL_COL    = "label_text" 

NUMERIC_COLS = [
    "y0", "y1", "dimension", "width", "height",
    "aspect_ratio", "date_range", "decade",
    "log_width", "log_height", "log_dim", "year_century",
    "has_txt", "has_tag", "has_note", "has_inscription",
]

CAT_COLS = [
    "classification", "visualbrowserclassification",
    "departmentabbr",
]

print(f"\nFeature groups:")
print(f"  Text cols : {TEXT_COL}")
print(f"  Numeric   : {len(NUMERIC_COLS)} cols")
print(f"  Categorical: {CAT_COLS}")
# Out:
# Feature groups:
#   Text cols : text_combined
#   Numeric   : 16 cols
#   Categorical: ['classification', 'visualbrowserclassification', 'departmentabbr']

# %%
def build_features(df, tfidf=None, enc=None, fit=True):
    """
    Returns a sparse feature matrix and fitted transformers.
    Set fit=True for train, fit=False for test (pass fitted tfidf/enc).
    """
    # TF-IDF on combined text
    if fit:
        tfidf = TfidfVectorizer(
            max_features=15000,
            ngram_range=(1, 2),
            sublinear_tf=True,
            min_df=2,
            strip_accents="unicode",
            analyzer="word",
        )
        X_text = tfidf.fit_transform(df[TEXT_COL])
    else:
        X_text = tfidf.transform(df[TEXT_COL])

    # Ordinal encode categoricals
    if fit:
        enc = OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1)
        X_cat = enc.fit_transform(df[CAT_COLS].fillna("unknown"))
    else:
        X_cat = enc.transform(df[CAT_COLS].fillna("unknown"))

    # Numeric (already clean)
    X_num = df[NUMERIC_COLS].values.astype(np.float32)

    # Stack everything into a sparse matrix
    X_cat_sp  = sp.csr_matrix(X_cat)
    X_num_sp  = sp.csr_matrix(X_num)
    X_final   = sp.hstack([X_text, X_cat_sp, X_num_sp])

    return X_final, tfidf, enc

X_feat, tfidf_fitted, enc_fitted = build_features(X, fit=True)
print(f"Feature matrix shape: {X_feat.shape}")
# Out:
# Feature matrix shape: (4000, 11352)

# %% [markdown]
# # **Models**

# %% [markdown]
# ## **Baseline Model**

# %%
# Use text-only features for speed
tfidf_quick = TfidfVectorizer(max_features=8000, sublinear_tf=True, ngram_range=(1,2))
X_text_only = tfidf_quick.fit_transform(X[TEXT_COL])

lr = LogisticRegression(max_iter=1000, C=1.0, class_weight="balanced", n_jobs=-1)
cv_scores = cross_val_score(lr, X_text_only, y,
                             cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=42),
                             scoring="f1_macro", n_jobs=-1)

print(f"Logistic Regression CV F1-macro: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# Logistic Regression CV F1-macro: 0.9570 ± 0.0020

# %%
feature_names = tfidf_quick.get_feature_names_out()
print(feature_names[:50])
# Out:
# ['05' '10' '11' '12' '12 99' '13' '13th' '13th century' '14' '14 by'
#  '14 mars' '15' '15 crane' '15th' '15th century' '16' '1682' '16th'
#  '16th century' '17' '1757' '17th' '17th century' '18' '1800' '1800 1859'
#  '181' '181 cm' '1859' '1859 audience' '1859 romantic' '1859 ulysses'
#  '18th' '18th century' '1900' '1900 1950' '1950' '1950 nga' '1950 to'
#  '1973' '19th' '19th century' '2009' '20th' '20th century' '21' '23'
#  '23 feb' '24' '2447']

# %%
# TF-IDF weights

def tfidf_weights(n):
    doc_idx = n
    row = X_text_only[doc_idx]

    indices = row.indices
    values = row.data

    print("=" * 60)
    print("Original text")
    print("=" * 60)

    print(X[TEXT_COL].iloc[n], "\n")

    print("=" * 60)
    print("TF-IDF Weights")
    print("=" * 60)
    for i, v in zip(indices[:20], values[:20]):
        print(feature_names[i], ":", v)

tfidf_weights(5)
# Out:
# ============================================================
# Original text
# ============================================================
# Madonna and Child Fra Filippo Lippi Painting painting Renaissance|painted surface|Madonna and Child|Italian Paintings of the Fifteenth Century|Florentine   A tempera artwork titled 'Madonna and Child' by Unknown Artist.
#
# ============================================================
# TF-IDF Weights
# ============================================================
# painting : 0.08578930876527409
# painted : 0.051048420986446526
# surface : 0.051077833799272575
# paintings : 0.05682753465999548
# of : 0.05338230863320034
# the : 0.05173200632594584
# century : 0.059967655519631645
# and : 0.14632909096627983
# artwork : 0.03130993695077363
# titled : 0.03130993695077363
# by : 0.03130993695077363
# unknown : 0.03130993695077363
# artist : 0.03130993695077363
# painting painting : 0.05085790826181245
# painted surface : 0.051077833799272575
# paintings of : 0.06116283638932291
# of the : 0.059482821784961774
# artwork titled : 0.03130993695077363
# by unknown : 0.03130993695077363
# unknown artist : 0.03130993695077363

# %% [markdown]
# ## **LightGBM**

# %%
PARAMS = {
    "objective":        "multiclass",
    "num_class":        len(CLASS_NAMES),
    "metric":           "multi_logloss",
    "learning_rate":    0.05,
    "num_leaves":       63,
    "max_depth":        -1,
    "min_child_samples": 20,
    "feature_fraction": 0.8,
    "bagging_fraction": 0.8,
    "bagging_freq":     5,
    "reg_alpha":        0.1,
    "reg_lambda":       0.1,
    "class_weight":     "balanced",   # handles imbalance
    "verbose":          -1,
    "n_jobs":           -1,
    "seed":             42,
}

N_FOLDS   = 5
N_ROUNDS  = 1000
EARLY_STOP = 50

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

oof_preds   = np.zeros((len(X), len(CLASS_NAMES)))   # out-of-fold probabilities
test_preds  = np.zeros((len(X_test), len(CLASS_NAMES)))
fold_scores = []

# Build test features once
X_test_feat, _, _ = build_features(X_test, tfidf=tfidf_fitted, enc=enc_fitted, fit=False)

for fold, (train_idx, val_idx) in enumerate(skf.split(X_feat, y), 1):
    print(f"\n  Fold {fold}/{N_FOLDS} —", end=" ")

    X_tr, X_val = X_feat[train_idx], X_feat[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    dtrain = lgb.Dataset(X_tr, label=y_tr)
    dval   = lgb.Dataset(X_val, label=y_val, reference=dtrain)

    callbacks = [
        lgb.early_stopping(EARLY_STOP, verbose=False),
        lgb.log_evaluation(period=-1),   # silent
    ]

    model = lgb.train(
        PARAMS,
        dtrain,
        num_boost_round=N_ROUNDS,
        valid_sets=[dval],
        callbacks=callbacks,
    )

    # OOF predictions
    oof_preds[val_idx] = model.predict(X_val)

    # Test predictions (average across folds)
    test_preds += model.predict(X_test_feat) / N_FOLDS

    fold_f1 = f1_score(y_val, oof_preds[val_idx].argmax(axis=1), average="macro")
    fold_scores.append(fold_f1)
    print(f"best iter={model.best_iteration}  |  val F1-macro={fold_f1:.4f}")

print(f"\nCV F1-macro: {np.mean(fold_scores):.4f} ± {np.std(fold_scores):.4f}")
# Out:
#   Fold 1/5 — best iter=87  |  val F1-macro=0.9730
#
#   Fold 2/5 — best iter=75  |  val F1-macro=0.9674
#
#   Fold 3/5 — best iter=75  |  val F1-macro=0.9736
#
#   Fold 4/5 — best iter=73  |  val F1-macro=0.9645
#
#   Fold 5/5 — best iter=75  |  val F1-macro=0.9673
#
# CV F1-macro: 0.9692 ± 0.0035

# %%
print("\n" + "=" * 60)
print("OOF Evaluation")
print("=" * 60)

oof_labels = oof_preds.argmax(axis=1)
print(f"\nOverall accuracy : {accuracy_score(y, oof_labels):.4f}")
print(f"F1-macro (OOF)   : {f1_score(y, oof_labels, average='macro'):.4f}")
print(f"F1-weighted (OOF): {f1_score(y, oof_labels, average='weighted'):.4f}")
print("\nPer-class report:")
print(classification_report(y, oof_labels,
                             target_names=list(CLASS_NAMES.values()),
                             digits=4))
# Out:
# ============================================================
# OOF Evaluation
# ============================================================
#
# Overall accuracy : 0.9695
# F1-macro (OOF)   : 0.9691
# F1-weighted (OOF): 0.9696
#
# Per-class report:
#                precision    recall  f1-score   support
#
#       acrylic     1.0000    1.0000    1.0000       500
# oil_on_canvas     0.8540    0.9369    0.8935       412
#   oil_on_wood     1.0000    0.9702    0.9849       571
#  oil_on_panel     0.9738    0.9878    0.9807       490
#    watercolor     0.9918    0.9979    0.9949       485
#       tempera     0.9698    1.0000    0.9847       482
#           ink     0.9780    0.9911    0.9845       449
#         print     0.9749    0.8887    0.9298       611
#
#      accuracy                         0.9695      4000
#     macro avg     0.9678    0.9716    0.9691      4000
#  weighted avg     0.9708    0.9695    0.9696      4000

# %%
cm = confusion_matrix(y, oof_labels)
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, axes = plt.subplots(1, 2, figsize=(14, 5.5))
fig.suptitle("OOF Confusion Matrix", fontsize=14, fontweight="500")

# Raw counts
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=list(CLASS_NAMES.values()),
            yticklabels=list(CLASS_NAMES.values()),
            ax=axes[0], linewidths=0.5, linecolor="#E8E6DE",
            annot_kws={"size": 9})
axes[0].set_title("Raw counts", fontsize=11)
axes[0].set_xlabel("Predicted"); axes[0].set_ylabel("Actual")
axes[0].tick_params(axis="x", rotation=40, labelsize=9)
axes[0].tick_params(axis="y", rotation=0, labelsize=9)

# Normalised
sns.heatmap(cm_norm, annot=True, fmt=".2f", cmap="Blues",
            xticklabels=list(CLASS_NAMES.values()),
            yticklabels=list(CLASS_NAMES.values()),
            ax=axes[1], linewidths=0.5, linecolor="#E8E6DE",
            annot_kws={"size": 9}, vmin=0, vmax=1)
axes[1].set_title("Recall (row-normalised)", fontsize=11)
axes[1].set_xlabel("Predicted"); axes[1].set_ylabel("")
axes[1].tick_params(axis="x", rotation=40, labelsize=9)
axes[1].tick_params(axis="y", rotation=0, labelsize=9)

plt.tight_layout()
plt.show()

# %%
n = 10
fi = model.feature_importance(importance_type="gain")
feature_names = (
    tfidf_fitted.get_feature_names_out().tolist() +
    CAT_COLS +
    NUMERIC_COLS
)
fi_df = (pd.DataFrame({"feature": feature_names, "importance": fi})
           .sort_values("importance", ascending=False)
           .head(n))

fig, ax = plt.subplots(figsize=(9, 7))
fig.suptitle(f"Top {n} features by gain (last fold)", fontsize=14, fontweight="500")
ax.barh(fi_df["feature"][::-1], fi_df["importance"][::-1],
        color="#378ADD", alpha=0.8, height=0.7)
ax.set_xlabel("Gain importance")
ax.tick_params(axis="y", labelsize=9)
ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Submission**

# %%
test_labels = test_preds.argmax(axis=1)

submission = pd.DataFrame({
    "id":  test["id"] if "id" in test.columns else range(len(test)),
    "y":   test_labels,
})
submission.to_csv("submission.csv", index=False)
print(f"Submission saved → submission.csv  ({len(submission)} rows)")
print(f"Predicted class distribution:\n{pd.Series(test_labels).map(CLASS_NAMES).value_counts()}")
# Out:
# ============================================================
#  Generating submission
# ============================================================
# Submission saved → submission.csv  (1000 rows)
# Predicted class distribution:
# oil_on_wood      138
# print            137
# tempera          127
# acrylic          125
# oil_on_panel     123
# watercolor       122
# ink              114
# oil_on_canvas    114
# Name: count, dtype: int64

# %%
joblib.dump(tfidf_fitted, "tfidf.pkl")
joblib.dump(enc_fitted,   "encoder.pkl")
print("\nArtefacts saved: tfidf.pkl, encoder.pkl")
print("\nDone.")
